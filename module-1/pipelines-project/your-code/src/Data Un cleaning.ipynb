# %%
import pandas as pd


data = pd.read_csv('../input/Table-Youth-and-Adult-Literacy-Rate-updated-Oct.-2015_78.csv', sep=';')

data = data.loc[:, data.isnull().sum() < 0.8*data.shape[0]]

# %%
data.head(50)
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2         Education: Adult literacy rate - Percentage
# 3                                                 NaN
# 4   Prepared by the Data and Analytics Section; Di...
# 5                                                 NaN
# 6                           Last update: October 2015
# 7                                                 NaN
# 8                                            ISO Code
# 9                                                 NaN
# 10                                                AFG
# 11                                                ALB
# 12                                                DZA
# 13                                                AND
# 14                                                AGO
# 15                                                ATG
# ...

# %%
data.columns = ['ISO Code', 'Countries and areas', 'Reference year(s)', 'Total', 'Male', 'Female', 'Extra']

# %%
data = data.dropna()
data.head()
# Out:
#    ISO Code  Countries and areas Reference year(s) Total Male Female  \
# 10      AFG          Afghanistan              2011    32   45     18
# 11      ALB              Albania              2011    97   98     96
# 12      DZA              Algeria              2006    73   81     64
# 14      AGO               Angola              2013    71   82     60
# 15      ATG  Antigua and Barbuda              2013    99   98     99
#
#                               Extra
# 10  UNESCO Institute for Statistics
# 11  UNESCO Institute for Statistics
# 12  UNESCO Institute for Statistics
# 14  UNESCO Institute for Statistics
# 15  UNESCO Institute for Statistics
